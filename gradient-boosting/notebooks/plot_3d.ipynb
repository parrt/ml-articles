# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D # required even though not ref'd!
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['mathtext.rm'] = 'serif'
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,8))
ax = fig.gca(projection='3d')

x = np.arange(0, 10, .1)
y = np.arange(0, 10, .1)
(x_mesh, y_mesh) = np.meshgrid(x, y)

eta = .08

def f(x,y):
    return (x-10)**2 + 4*(y-5)**2# if x<10.3 else 0

def df(x,y): return np.array([2*(x-10), 8*(y-5)])

z = np.array([f(x,y) for x,y in zip(np.ravel(x_mesh), np.ravel(y_mesh))])
Z = z.reshape(x_mesh.shape)

ax.contour3D(x, y, Z, 60)

start = np.array([5,1])
delta = df(*start)
print("start",start)
print("df",delta)
print("eta * df", eta * delta)
next = start -(eta * delta)

print("next",next)

print([start[0],start[0]+delta[0]])
print([start[1],start[1]+delta[1]])
print([f(*start),f(*(start+delta))])

#ax.plot([start[0],next[0]],[start[1],next[1]],[f(*start),f(next[0],next[1])])

#ax.arrow(*start, *(-(eta * delta)), head_width=5, head_length=3)

ax.set_xlabel('$x$', fontsize=24)
ax.set_ylabel('$y$', fontsize=24)
ax.set_zlabel('$z$', rotation='vertical', fontsize=24)
# ax.set_xticks([-10,-5,0,5,10])
# ax.set_yticks([-10,-5,0,5,10])
# ax.set_xlim(0,10)
# ax.set_ylim(0,15)
ax.grid(False)
ax.xaxis.pane.set_edgecolor('black')
ax.yaxis.pane.set_edgecolor('black')
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.view_init(30, 20)
plt.tight_layout()

plt.savefig('mtn-3d.pdf')
plt.show()
# Out:
# start [5 1]
# df [-10 -32]
# eta * df [-0.8  -2.56]
# next [5.8  3.56]
# [5, -5]
# [1, -31]
# [89, 5409]

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D # required even though not ref'd!
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['mathtext.rm'] = 'serif'
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
import matplotlib.cm as cm

fig, ax = plt.subplots()

x = np.arange(0, 10, .1)
y = np.arange(0, 10, .1)
(x_mesh, y_mesh) = np.meshgrid(x, y)

def f(x,y):
    return (x-10)**2 + 4*(y-5)**2# if x<10.3 else 0

def df(x,y): return np.array([2*(x-10), 8*(y-5)])

z = np.array([f(x,y) for x,y in zip(np.ravel(x_mesh), np.ravel(y_mesh))])
Z = z.reshape(x_mesh.shape)
print(Z)

im = ax.imshow(Z, extent=[0,10,0,10], origin='lower', cmap=cm.Blues)

start = [20,80]
ax.arrow(*start,-1,-3.2)

plt.show()
# Out:
# [[200.   198.01 196.04 ... 100.09 100.04 100.01]
#  [196.04 194.05 192.08 ...  96.13  96.08  96.05]
#  [192.16 190.17 188.2  ...  92.25  92.2   92.17]
#  ...
#  [188.36 186.37 184.4  ...  88.45  88.4   88.37]
#  [192.16 190.17 188.2  ...  92.25  92.2   92.17]
#  [196.04 194.05 192.08 ...  96.13  96.08  96.05]]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['mathtext.rm'] = 'serif'
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 

fig, ax = plt.subplots(figsize=(5,3))

def f(x): return (x-5)**2 + 2
def df(x): return 2*(x-5)

x = np.arange(0, 10, .1)
ax.plot(x,f(x))

eta = 1
# for x in [2.5, 5.2, 6.5]:
#     ax.arrow(x, f(x), - eta * df(x), f(x - eta * df(x)), head_width=0.1, head_length=0.2, color='r', linewidth=2)
# ax.arrow(5.2,f(5.2), eta * 1, eta * df(5.2), head_width=0.1, head_length=0.1, color='r', linewidth=2)
# ax.arrow(6.5,f(6.5), eta * 1, eta * df(6.5), head_width=0.1, head_length=0.2, color='r', linewidth=2)

px = 2.5
qx = px - eta * df(px)

line = df(px)

# print(px,qx)
# ax.annotate("", xytext=(px,f(px)), xy=(qx,f(qx)),
#     arrowprops=dict(arrowstyle="->"))

#ax.text(2.6, f(2.5), r"$\frac{\partial f}{\partial x}$", fontsize=20)

ax.plot([2.5,])

ax.set_ylim(0,20)
ax.set_xlim(0,10)
ax.set_ylabel("$f(x)$", fontsize=20)
ax.set_xlabel("$x$", fontsize=20)

plt.tight_layout()
plt.savefig('../images/tangents.pdf')
plt.show()
